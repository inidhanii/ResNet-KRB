# %% [markdown]
# # ResNet-34 Transfer Learning for Plant Classification
# One Additional Hidden layer

# %%
import torch
import torch.nn as nn
from torch.optim import Adam
from torchvision import models, transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import RandAugment
import matplotlib.pyplot as plt
import time

# %%
train_transform = transforms.Compose([
    RandAugment(),  #RandAug
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  #Imagenet mean & std
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
train_folder = r"C:\Users\dhani\Documents\Tugas Akhir and Stuff\Dataset Manual\train"
test_folder = r"C:\Users\dhani\Documents\Tugas Akhir and Stuff\Dataset Manual\test"

train_dataset = ImageFolder(root=train_folder, transform=train_transform)
test_dataset = ImageFolder(root=test_folder, transform=test_transform)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train dataset: {len(train_dataset)} images, {len(train_dataset.classes)} classes.")
print(f"Test dataset: {len(test_dataset)} images, {len(test_dataset.classes)} classes.")
# Out:
# Train dataset: 3120 images, 52 classes.
# Test dataset: 2080 images, 52 classes.

# %%
from torchvision.models import resnet34, ResNet34_Weights, resnet50, ResNet50_Weights, resnet101,ResNet101_Weights

weights34 = ResNet34_Weights.IMAGENET1K_V1
weights50 = ResNet50_Weights.IMAGENET1K_V1
weights101 = ResNet101_Weights.IMAGENET1K_V1
model = resnet34(weights=weights34)

#freeze conv
for param in model.parameters():
    param.requires_grad = False

# fc layer config
num_classes = 52
# zerolayer
# model.fc = nn.Linear(model.fc.in_features, num_classes)  

# onelayer
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 512),
    nn.ReLU(),
    nn.Linear(512, num_classes)        
)       

# twolayer
# model.fc = nn.Sequential(
#     nn.Linear(model.fc.in_features, 512),
#     nn.ReLU(),
#     nn.Linear(512, 512),
#     nn.ReLU(),
#     nn.Linear(512, num_classes)        
# )                                                      

#parameter set
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.fc.parameters(), lr=0.001)

device = torch.device('cuda')
model = model.to(device)

# %%
import pandas as pd
import torch
import torch.nn as nn
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import time

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_f1_scores = []
val_f1_scores = []

total_start_time = time.time()

num_epochs = 50

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    all_train_labels = []
    all_train_preds = []

    start_time = time.time()

    # Train loop
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        # Forwardprop
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        all_train_labels.extend(labels.cpu().numpy())
        all_train_preds.extend(predicted.cpu().numpy())

    # Train loss, accuracy, F1 score
    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train
    train_f1 = f1_score(all_train_labels, all_train_preds, average='macro')

    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    train_f1_scores.append(train_f1)

    # Validation loop
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    all_val_labels = []
    all_val_preds = []
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

            all_val_labels.extend(labels.cpu().numpy())
            all_val_preds.extend(predicted.cpu().numpy())

    # Val loss, accuracy,  F1 score
    val_loss = val_loss / len(test_loader)
    val_accuracy = 100 * correct_val / total_val
    val_f1 = f1_score(all_val_labels, all_val_preds, average='macro')

    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)
    val_f1_scores.append(val_f1)

    epoch_time = time.time() - start_time

    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, "
          f"Train Accuracy: {train_accuracy:.2f}%, Val Accuracy: {val_accuracy:.2f}%, "
          f"Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}, Time: {epoch_time:.2f} seconds")

total_training_time = time.time() - total_start_time
print(f"Total Training Time: {total_training_time:.2f} seconds")

results_df = pd.DataFrame({
    'Epoch': range(1, num_epochs + 1),
    'Train Loss': train_losses,
    'Val Loss': val_losses,
    'Train Accuracy': train_accuracies,
    'Val Accuracy': val_accuracies,
    'Train F1 Score': train_f1_scores,
    'Val F1 Score': val_f1_scores
})
results_df.to_csv('training_results_with_34_1.csv', index=False)
# Out:
# Epoch [1/50], Train Loss: 2.6771, Val Loss: 1.1494, Train Accuracy: 37.88%, Val Accuracy: 76.73%, Train F1: 0.3826, Val F1: 0.7427, Time: 29.70 seconds
# Epoch [2/50], Train Loss: 1.1572, Val Loss: 0.6663, Train Accuracy: 71.03%, Val Accuracy: 81.97%, Train F1: 0.7041, Val F1: 0.8158, Time: 23.56 seconds
# Epoch [3/50], Train Loss: 0.8357, Val Loss: 0.5044, Train Accuracy: 77.24%, Val Accuracy: 85.91%, Train F1: 0.7709, Val F1: 0.8555, Time: 24.17 seconds
# Epoch [4/50], Train Loss: 0.6704, Val Loss: 0.4278, Train Accuracy: 81.63%, Val Accuracy: 87.31%, Train F1: 0.8147, Val F1: 0.8686, Time: 24.79 seconds
# Epoch [5/50], Train Loss: 0.5643, Val Loss: 0.3455, Train Accuracy: 84.20%, Val Accuracy: 90.29%, Train F1: 0.8411, Val F1: 0.9019, Time: 23.85 seconds
# Epoch [6/50], Train Loss: 0.5214, Val Loss: 0.3316, Train Accuracy: 85.10%, Val Accuracy: 90.10%, Train F1: 0.8499, Val F1: 0.8980, Time: 23.65 seconds
# Epoch [7/50], Train Loss: 0.5240, Val Loss: 0.2849, Train Accuracy: 84.52%, Val Accuracy: 92.07%, Train F1: 0.8448, Val F1: 0.9221, Time: 24.23 seconds
# Epoch [8/50], Train Loss: 0.4091, Val Loss: 0.2796, Train Accuracy: 87.56%, Val Accuracy: 91.68%, Train F1: 0.8755, Val F1: 0.9163, Time: 25.53 seconds
# Epoch [9/50], Train Loss: 0.4138, Val Loss: 0.3050, Train Accuracy: 87.53%, Val Accuracy: 90.43%, Train F1: 0.8754, Val F1: 0.9029, Time: 23.86 seconds
# Epoch [10/50], Train Loss: 0.4411, Val Loss: 0.3288, Train Accuracy: 87.18%, Val Accuracy: 89.52%, Train F1: 0.8718, Val F1: 0.8973, Time: 23.74 seconds
# Epoch [11/50], Train Loss: 0.3956, Val Loss: 0.2343, Train Accuracy: 88.11%, Val Accuracy: 92.12%, Train F1: 0.8806, Val F1: 0.9219, Time: 23.89 seconds
# Epoch [12/50], Train Loss: 0.3570, Val Loss: 0.2566, Train Accuracy: 88.81%, Val Accuracy: 92.21%, Train F1: 0.8879, Val F1: 0.9214, Time: 23.97 seconds
# Epoch [13/50], Train Loss: 0.3719, Val Loss: 0.2456, Train Accuracy: 89.20%, Val Accuracy: 92.07%, Train F1: 0.8917, Val F1: 0.9206, Time: 23.94 seconds
# Epoch [14/50], Train Loss: 0.3291, Val Loss: 0.2629, Train Accuracy: 90.26%, Val Accuracy: 91.11%, Train F1: 0.9023, Val F1: 0.9116, Time: 24.15 seconds
# Epoch [15/50], Train Loss: 0.3250, Val Loss: 0.2203, Train Accuracy: 90.10%, Val Accuracy: 92.84%, Train F1: 0.9007, Val F1: 0.9281, Time: 24.83 seconds
# Epoch [16/50], Train Loss: 0.3273, Val Loss: 0.2014, Train Accuracy: 89.74%, Val Accuracy: 93.41%, Train F1: 0.8973, Val F1: 0.9341, Time: 24.04 seconds
# Epoch [17/50], Train Loss: 0.2930, Val Loss: 0.2398, Train Accuracy: 91.28%, Val Accuracy: 92.50%, Train F1: 0.9127, Val F1: 0.9244, Time: 23.99 seconds
# Epoch [18/50], Train Loss: 0.2972, Val Loss: 0.2248, Train Accuracy: 90.48%, Val Accuracy: 92.79%, Train F1: 0.9046, Val F1: 0.9278, Time: 24.13 seconds
# Epoch [19/50], Train Loss: 0.2832, Val Loss: 0.2044, Train Accuracy: 91.35%, Val Accuracy: 94.13%, Train F1: 0.9130, Val F1: 0.9424, Time: 24.19 seconds
# Epoch [20/50], Train Loss: 0.2854, Val Loss: 0.2029, Train Accuracy: 90.58%, Val Accuracy: 93.22%, Train F1: 0.9053, Val F1: 0.9324, Time: 24.10 seconds
# Epoch [21/50], Train Loss: 0.2771, Val Loss: 0.2278, Train Accuracy: 91.38%, Val Accuracy: 92.60%, Train F1: 0.9138, Val F1: 0.9257, Time: 24.21 seconds
# Epoch [22/50], Train Loss: 0.2812, Val Loss: 0.2129, Train Accuracy: 91.38%, Val Accuracy: 93.03%, Train F1: 0.9135, Val F1: 0.9308, Time: 24.29 seconds
# Epoch [23/50], Train Loss: 0.2809, Val Loss: 0.1989, Train Accuracy: 91.38%, Val Accuracy: 93.12%, Train F1: 0.9137, Val F1: 0.9315, Time: 24.46 seconds
# Epoch [24/50], Train Loss: 0.2821, Val Loss: 0.2236, Train Accuracy: 91.47%, Val Accuracy: 92.98%, Train F1: 0.9146, Val F1: 0.9300, Time: 24.47 seconds
# Epoch [25/50], Train Loss: 0.2999, Val Loss: 0.2026, Train Accuracy: 90.35%, Val Accuracy: 93.70%, Train F1: 0.9033, Val F1: 0.9379, Time: 24.47 seconds
# Epoch [26/50], Train Loss: 0.2742, Val Loss: 0.2043, Train Accuracy: 91.06%, Val Accuracy: 93.51%, Train F1: 0.9106, Val F1: 0.9343, Time: 26.29 seconds
# Epoch [27/50], Train Loss: 0.2573, Val Loss: 0.1920, Train Accuracy: 92.02%, Val Accuracy: 94.23%, Train F1: 0.9199, Val F1: 0.9424, Time: 24.76 seconds
# Epoch [28/50], Train Loss: 0.2476, Val Loss: 0.2189, Train Accuracy: 92.34%, Val Accuracy: 92.93%, Train F1: 0.9234, Val F1: 0.9291, Time: 24.72 seconds
# Epoch [29/50], Train Loss: 0.2337, Val Loss: 0.2177, Train Accuracy: 93.43%, Val Accuracy: 92.98%, Train F1: 0.9340, Val F1: 0.9304, Time: 27.04 seconds
# Epoch [30/50], Train Loss: 0.2357, Val Loss: 0.2527, Train Accuracy: 92.82%, Val Accuracy: 92.36%, Train F1: 0.9280, Val F1: 0.9240, Time: 27.50 seconds
# Epoch [31/50], Train Loss: 0.2662, Val Loss: 0.1870, Train Accuracy: 91.60%, Val Accuracy: 93.56%, Train F1: 0.9159, Val F1: 0.9349, Time: 25.65 seconds
# Epoch [32/50], Train Loss: 0.2392, Val Loss: 0.1998, Train Accuracy: 92.69%, Val Accuracy: 94.18%, Train F1: 0.9269, Val F1: 0.9418, Time: 25.64 seconds
# Epoch [33/50], Train Loss: 0.2220, Val Loss: 0.1655, Train Accuracy: 92.72%, Val Accuracy: 95.00%, Train F1: 0.9270, Val F1: 0.9498, Time: 24.80 seconds
# Epoch [34/50], Train Loss: 0.2393, Val Loss: 0.1890, Train Accuracy: 92.08%, Val Accuracy: 93.75%, Train F1: 0.9209, Val F1: 0.9377, Time: 25.61 seconds
# Epoch [35/50], Train Loss: 0.2170, Val Loss: 0.1930, Train Accuracy: 93.49%, Val Accuracy: 94.13%, Train F1: 0.9349, Val F1: 0.9421, Time: 25.54 seconds
# Epoch [36/50], Train Loss: 0.2112, Val Loss: 0.1828, Train Accuracy: 93.69%, Val Accuracy: 94.28%, Train F1: 0.9368, Val F1: 0.9429, Time: 25.39 seconds
# Epoch [37/50], Train Loss: 0.2314, Val Loss: 0.1815, Train Accuracy: 92.66%, Val Accuracy: 94.38%, Train F1: 0.9266, Val F1: 0.9431, Time: 25.17 seconds
# Epoch [38/50], Train Loss: 0.1858, Val Loss: 0.1621, Train Accuracy: 94.39%, Val Accuracy: 94.71%, Train F1: 0.9439, Val F1: 0.9473, Time: 25.28 seconds
# Epoch [39/50], Train Loss: 0.2076, Val Loss: 0.1745, Train Accuracy: 93.27%, Val Accuracy: 94.52%, Train F1: 0.9328, Val F1: 0.9454, Time: 25.72 seconds
# Epoch [40/50], Train Loss: 0.2090, Val Loss: 0.1734, Train Accuracy: 93.56%, Val Accuracy: 94.66%, Train F1: 0.9354, Val F1: 0.9468, Time: 25.35 seconds
# Epoch [41/50], Train Loss: 0.1946, Val Loss: 0.1755, Train Accuracy: 93.88%, Val Accuracy: 94.76%, Train F1: 0.9387, Val F1: 0.9477, Time: 25.45 seconds
# Epoch [42/50], Train Loss: 0.1960, Val Loss: 0.2050, Train Accuracy: 93.56%, Val Accuracy: 93.22%, Train F1: 0.9356, Val F1: 0.9311, Time: 25.56 seconds
# Epoch [43/50], Train Loss: 0.2019, Val Loss: 0.2187, Train Accuracy: 93.21%, Val Accuracy: 92.98%, Train F1: 0.9319, Val F1: 0.9307, Time: 25.06 seconds
# Epoch [44/50], Train Loss: 0.1975, Val Loss: 0.2123, Train Accuracy: 93.59%, Val Accuracy: 93.99%, Train F1: 0.9358, Val F1: 0.9399, Time: 25.54 seconds
# Epoch [45/50], Train Loss: 0.2061, Val Loss: 0.1924, Train Accuracy: 93.40%, Val Accuracy: 94.38%, Train F1: 0.9340, Val F1: 0.9440, Time: 25.76 seconds
# Epoch [46/50], Train Loss: 0.2089, Val Loss: 0.1657, Train Accuracy: 93.37%, Val Accuracy: 94.86%, Train F1: 0.9336, Val F1: 0.9483, Time: 25.39 seconds
# Epoch [47/50], Train Loss: 0.1816, Val Loss: 0.2003, Train Accuracy: 94.20%, Val Accuracy: 93.80%, Train F1: 0.9420, Val F1: 0.9383, Time: 25.84 seconds
# Epoch [48/50], Train Loss: 0.1875, Val Loss: 0.1689, Train Accuracy: 93.78%, Val Accuracy: 94.71%, Train F1: 0.9378, Val F1: 0.9476, Time: 25.62 seconds
# Epoch [49/50], Train Loss: 0.2044, Val Loss: 0.1926, Train Accuracy: 93.43%, Val Accuracy: 93.99%, Train F1: 0.9344, Val F1: 0.9398, Time: 25.30 seconds
# Epoch [50/50], Train Loss: 0.1755, Val Loss: 0.2088, Train Accuracy: 94.52%, Val Accuracy: 93.32%, Train F1: 0.9451, Val F1: 0.9332, Time: 25.92 seconds
# Total Training Time: 1250.17 seconds

# %%
#savemodel
torch.save(model.state_dict(), "resnet34_OneLayer.pth")
