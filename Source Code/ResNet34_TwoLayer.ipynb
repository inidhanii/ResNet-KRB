# %% [markdown]
# # ResNet-34 Transfer Learning for Plant Classification
# Two Additional Hidden Layer

# %%
import torch
import torch.nn as nn
from torch.optim import Adam
from torchvision import models, transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import RandAugment
import matplotlib.pyplot as plt
import time

# %%
train_transform = transforms.Compose([
    RandAugment(),  #RandAug
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  #Imagenet mean & std
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
train_folder = r"C:\Users\dhani\Documents\Tugas Akhir and Stuff\Dataset Manual\train"
test_folder = r"C:\Users\dhani\Documents\Tugas Akhir and Stuff\Dataset Manual\test"

train_dataset = ImageFolder(root=train_folder, transform=train_transform)
test_dataset = ImageFolder(root=test_folder, transform=test_transform)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train dataset: {len(train_dataset)} images, {len(train_dataset.classes)} classes.")
print(f"Test dataset: {len(test_dataset)} images, {len(test_dataset.classes)} classes.")
# Out:
# Train dataset: 3120 images, 52 classes.
# Test dataset: 2080 images, 52 classes.

# %%
from torchvision.models import resnet34, ResNet34_Weights, resnet50, ResNet50_Weights, resnet101,ResNet101_Weights

weights34 = ResNet34_Weights.IMAGENET1K_V1
weights50 = ResNet50_Weights.IMAGENET1K_V1
weights101 = ResNet101_Weights.IMAGENET1K_V1
model = resnet34(weights=weights34)

#freeze conv
for param in model.parameters():
    param.requires_grad = False

# fc layer config
num_classes = 52
# zerolayer
# model.fc = nn.Linear(model.fc.in_features, num_classes)  

# onelayer
# model.fc = nn.Sequential(
#     nn.Linear(model.fc.in_features, 512),
#     nn.ReLU(),
#     nn.Linear(512, num_classes)        
# )       

# twolayer
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 512),
    nn.ReLU(),
    nn.Linear(512, 512),
    nn.ReLU(),
    nn.Linear(512, num_classes)        
)                                                      

#parameter set
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.fc.parameters(), lr=0.001)

device = torch.device('cuda')
model = model.to(device)

# %%
import pandas as pd
import torch
import torch.nn as nn
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import time

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_f1_scores = []
val_f1_scores = []

total_start_time = time.time()

num_epochs = 50

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    all_train_labels = []
    all_train_preds = []

    start_time = time.time()

    # Train loop
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        # Forwardprop
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        all_train_labels.extend(labels.cpu().numpy())
        all_train_preds.extend(predicted.cpu().numpy())

    # Train loss, accuracy, F1 score
    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train
    train_f1 = f1_score(all_train_labels, all_train_preds, average='macro')

    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    train_f1_scores.append(train_f1)

    # Validation loop
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    all_val_labels = []
    all_val_preds = []
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

            all_val_labels.extend(labels.cpu().numpy())
            all_val_preds.extend(predicted.cpu().numpy())

    # Val loss, accuracy,  F1 score
    val_loss = val_loss / len(test_loader)
    val_accuracy = 100 * correct_val / total_val
    val_f1 = f1_score(all_val_labels, all_val_preds, average='macro')

    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)
    val_f1_scores.append(val_f1)

    epoch_time = time.time() - start_time

    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, "
          f"Train Accuracy: {train_accuracy:.2f}%, Val Accuracy: {val_accuracy:.2f}%, "
          f"Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}, Time: {epoch_time:.2f} seconds")

total_training_time = time.time() - total_start_time
print(f"Total Training Time: {total_training_time:.2f} seconds")

results_df = pd.DataFrame({
    'Epoch': range(1, num_epochs + 1),
    'Train Loss': train_losses,
    'Val Loss': val_losses,
    'Train Accuracy': train_accuracies,
    'Val Accuracy': val_accuracies,
    'Train F1 Score': train_f1_scores,
    'Val F1 Score': val_f1_scores
})
results_df.to_csv('training_results_with_34_2.csv', index=False)
# Out:
# Epoch [1/50], Train Loss: 2.7124, Val Loss: 1.3177, Train Accuracy: 31.28%, Val Accuracy: 61.83%, Train F1: 0.2998, Val F1: 0.5875, Time: 24.56 seconds
# Epoch [2/50], Train Loss: 1.2590, Val Loss: 0.7181, Train Accuracy: 65.29%, Val Accuracy: 79.86%, Train F1: 0.6478, Val F1: 0.7845, Time: 24.83 seconds
# Epoch [3/50], Train Loss: 0.8993, Val Loss: 0.5545, Train Accuracy: 74.36%, Val Accuracy: 82.74%, Train F1: 0.7392, Val F1: 0.8256, Time: 25.39 seconds
# Epoch [4/50], Train Loss: 0.7607, Val Loss: 0.4420, Train Accuracy: 77.21%, Val Accuracy: 85.77%, Train F1: 0.7706, Val F1: 0.8580, Time: 25.47 seconds
# Epoch [5/50], Train Loss: 0.7144, Val Loss: 0.4503, Train Accuracy: 78.65%, Val Accuracy: 85.91%, Train F1: 0.7847, Val F1: 0.8521, Time: 25.01 seconds
# Epoch [6/50], Train Loss: 0.6163, Val Loss: 0.3684, Train Accuracy: 81.22%, Val Accuracy: 88.80%, Train F1: 0.8109, Val F1: 0.8895, Time: 25.08 seconds
# Epoch [7/50], Train Loss: 0.5503, Val Loss: 0.3807, Train Accuracy: 82.92%, Val Accuracy: 87.12%, Train F1: 0.8278, Val F1: 0.8753, Time: 26.18 seconds
# Epoch [8/50], Train Loss: 0.5262, Val Loss: 0.3363, Train Accuracy: 83.62%, Val Accuracy: 89.18%, Train F1: 0.8357, Val F1: 0.8913, Time: 26.21 seconds
# Epoch [9/50], Train Loss: 0.4705, Val Loss: 0.3148, Train Accuracy: 85.16%, Val Accuracy: 90.05%, Train F1: 0.8513, Val F1: 0.8985, Time: 27.81 seconds
# Epoch [10/50], Train Loss: 0.4561, Val Loss: 0.2772, Train Accuracy: 85.90%, Val Accuracy: 90.96%, Train F1: 0.8580, Val F1: 0.9100, Time: 29.37 seconds
# Epoch [11/50], Train Loss: 0.4438, Val Loss: 0.2441, Train Accuracy: 86.22%, Val Accuracy: 91.63%, Train F1: 0.8614, Val F1: 0.9164, Time: 26.11 seconds
# Epoch [12/50], Train Loss: 0.3823, Val Loss: 0.3054, Train Accuracy: 88.17%, Val Accuracy: 90.62%, Train F1: 0.8815, Val F1: 0.9045, Time: 25.63 seconds
# Epoch [13/50], Train Loss: 0.4266, Val Loss: 0.2458, Train Accuracy: 87.02%, Val Accuracy: 91.63%, Train F1: 0.8694, Val F1: 0.9168, Time: 25.42 seconds
# Epoch [14/50], Train Loss: 0.3814, Val Loss: 0.2353, Train Accuracy: 88.01%, Val Accuracy: 92.55%, Train F1: 0.8799, Val F1: 0.9270, Time: 26.78 seconds
# Epoch [15/50], Train Loss: 0.3769, Val Loss: 0.2995, Train Accuracy: 87.60%, Val Accuracy: 91.15%, Train F1: 0.8758, Val F1: 0.9116, Time: 26.03 seconds
# Epoch [16/50], Train Loss: 0.4017, Val Loss: 0.2468, Train Accuracy: 87.12%, Val Accuracy: 92.69%, Train F1: 0.8705, Val F1: 0.9262, Time: 27.08 seconds
# Epoch [17/50], Train Loss: 0.3386, Val Loss: 0.2859, Train Accuracy: 89.13%, Val Accuracy: 91.30%, Train F1: 0.8910, Val F1: 0.9135, Time: 26.16 seconds
# Epoch [18/50], Train Loss: 0.3126, Val Loss: 0.2365, Train Accuracy: 90.67%, Val Accuracy: 92.84%, Train F1: 0.9067, Val F1: 0.9288, Time: 25.95 seconds
# Epoch [19/50], Train Loss: 0.3053, Val Loss: 0.2816, Train Accuracy: 91.12%, Val Accuracy: 91.97%, Train F1: 0.9111, Val F1: 0.9207, Time: 26.22 seconds
# Epoch [20/50], Train Loss: 0.3235, Val Loss: 0.2691, Train Accuracy: 90.03%, Val Accuracy: 91.35%, Train F1: 0.9001, Val F1: 0.9122, Time: 25.95 seconds
# Epoch [21/50], Train Loss: 0.3124, Val Loss: 0.2384, Train Accuracy: 89.71%, Val Accuracy: 92.64%, Train F1: 0.8967, Val F1: 0.9261, Time: 25.95 seconds
# Epoch [22/50], Train Loss: 0.2836, Val Loss: 0.2755, Train Accuracy: 90.80%, Val Accuracy: 91.39%, Train F1: 0.9077, Val F1: 0.9127, Time: 25.89 seconds
# Epoch [23/50], Train Loss: 0.3227, Val Loss: 0.2017, Train Accuracy: 90.19%, Val Accuracy: 93.56%, Train F1: 0.9018, Val F1: 0.9361, Time: 26.26 seconds
# Epoch [24/50], Train Loss: 0.2904, Val Loss: 0.2023, Train Accuracy: 90.48%, Val Accuracy: 93.80%, Train F1: 0.9045, Val F1: 0.9389, Time: 25.12 seconds
# Epoch [25/50], Train Loss: 0.2863, Val Loss: 0.2181, Train Accuracy: 90.99%, Val Accuracy: 93.70%, Train F1: 0.9100, Val F1: 0.9371, Time: 24.79 seconds
# Epoch [26/50], Train Loss: 0.2749, Val Loss: 0.2330, Train Accuracy: 91.19%, Val Accuracy: 93.46%, Train F1: 0.9118, Val F1: 0.9346, Time: 24.95 seconds
# Epoch [27/50], Train Loss: 0.2871, Val Loss: 0.2177, Train Accuracy: 91.09%, Val Accuracy: 93.80%, Train F1: 0.9108, Val F1: 0.9389, Time: 24.92 seconds
# Epoch [28/50], Train Loss: 0.2951, Val Loss: 0.1906, Train Accuracy: 90.51%, Val Accuracy: 93.85%, Train F1: 0.9051, Val F1: 0.9387, Time: 25.03 seconds
# Epoch [29/50], Train Loss: 0.2566, Val Loss: 0.2210, Train Accuracy: 91.89%, Val Accuracy: 92.74%, Train F1: 0.9189, Val F1: 0.9276, Time: 24.84 seconds
# Epoch [30/50], Train Loss: 0.2402, Val Loss: 0.2120, Train Accuracy: 91.96%, Val Accuracy: 93.56%, Train F1: 0.9197, Val F1: 0.9357, Time: 24.85 seconds
# Epoch [31/50], Train Loss: 0.2512, Val Loss: 0.2078, Train Accuracy: 92.08%, Val Accuracy: 93.65%, Train F1: 0.9207, Val F1: 0.9369, Time: 24.90 seconds
# Epoch [32/50], Train Loss: 0.2699, Val Loss: 0.2029, Train Accuracy: 91.41%, Val Accuracy: 93.56%, Train F1: 0.9143, Val F1: 0.9349, Time: 24.87 seconds
# Epoch [33/50], Train Loss: 0.2509, Val Loss: 0.1893, Train Accuracy: 92.08%, Val Accuracy: 94.47%, Train F1: 0.9210, Val F1: 0.9444, Time: 25.00 seconds
# Epoch [34/50], Train Loss: 0.2443, Val Loss: 0.2119, Train Accuracy: 92.47%, Val Accuracy: 93.56%, Train F1: 0.9246, Val F1: 0.9356, Time: 25.09 seconds
# Epoch [35/50], Train Loss: 0.2467, Val Loss: 0.1961, Train Accuracy: 92.21%, Val Accuracy: 93.75%, Train F1: 0.9220, Val F1: 0.9377, Time: 25.27 seconds
# Epoch [36/50], Train Loss: 0.2187, Val Loss: 0.2341, Train Accuracy: 92.98%, Val Accuracy: 93.08%, Train F1: 0.9298, Val F1: 0.9306, Time: 24.76 seconds
# Epoch [37/50], Train Loss: 0.2514, Val Loss: 0.1943, Train Accuracy: 91.76%, Val Accuracy: 93.80%, Train F1: 0.9177, Val F1: 0.9388, Time: 24.77 seconds
# Epoch [38/50], Train Loss: 0.2164, Val Loss: 0.1765, Train Accuracy: 92.92%, Val Accuracy: 94.28%, Train F1: 0.9293, Val F1: 0.9430, Time: 25.02 seconds
# Epoch [39/50], Train Loss: 0.2172, Val Loss: 0.2191, Train Accuracy: 93.01%, Val Accuracy: 93.22%, Train F1: 0.9300, Val F1: 0.9315, Time: 24.83 seconds
# Epoch [40/50], Train Loss: 0.2182, Val Loss: 0.2257, Train Accuracy: 93.11%, Val Accuracy: 93.37%, Train F1: 0.9311, Val F1: 0.9331, Time: 25.07 seconds
# Epoch [41/50], Train Loss: 0.2267, Val Loss: 0.2255, Train Accuracy: 92.40%, Val Accuracy: 92.84%, Train F1: 0.9240, Val F1: 0.9295, Time: 24.83 seconds
# Epoch [42/50], Train Loss: 0.2085, Val Loss: 0.1798, Train Accuracy: 92.88%, Val Accuracy: 94.47%, Train F1: 0.9288, Val F1: 0.9457, Time: 24.86 seconds
# Epoch [43/50], Train Loss: 0.2080, Val Loss: 0.1986, Train Accuracy: 92.95%, Val Accuracy: 93.80%, Train F1: 0.9296, Val F1: 0.9381, Time: 25.03 seconds
# Epoch [44/50], Train Loss: 0.2388, Val Loss: 0.1683, Train Accuracy: 92.53%, Val Accuracy: 94.86%, Train F1: 0.9252, Val F1: 0.9483, Time: 24.80 seconds
# Epoch [45/50], Train Loss: 0.1994, Val Loss: 0.1806, Train Accuracy: 93.33%, Val Accuracy: 94.76%, Train F1: 0.9334, Val F1: 0.9472, Time: 24.71 seconds
# Epoch [46/50], Train Loss: 0.2036, Val Loss: 0.1761, Train Accuracy: 93.59%, Val Accuracy: 94.76%, Train F1: 0.9358, Val F1: 0.9476, Time: 25.02 seconds
# Epoch [47/50], Train Loss: 0.2105, Val Loss: 0.1759, Train Accuracy: 93.30%, Val Accuracy: 95.05%, Train F1: 0.9328, Val F1: 0.9503, Time: 24.99 seconds
# Epoch [48/50], Train Loss: 0.1934, Val Loss: 0.1762, Train Accuracy: 93.69%, Val Accuracy: 94.57%, Train F1: 0.9366, Val F1: 0.9450, Time: 25.13 seconds
# Epoch [49/50], Train Loss: 0.1939, Val Loss: 0.1861, Train Accuracy: 93.69%, Val Accuracy: 94.66%, Train F1: 0.9368, Val F1: 0.9465, Time: 24.94 seconds
# Epoch [50/50], Train Loss: 0.2160, Val Loss: 0.1921, Train Accuracy: 93.65%, Val Accuracy: 93.94%, Train F1: 0.9365, Val F1: 0.9393, Time: 25.07 seconds
# Total Training Time: 1272.83 seconds

# %%
#savemodel
torch.save(model.state_dict(), "resnet34_TwoLayer.pth")
