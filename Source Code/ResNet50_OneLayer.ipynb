# %% [markdown]
# # ResNet-50 Transfer Learning for Plant Classification
# One Additional Hidden Layer

# %%
import torch
import torch.nn as nn
from torch.optim import Adam
from torchvision import models, transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import RandAugment
import matplotlib.pyplot as plt
import time

# %%
train_transform = transforms.Compose([
    RandAugment(),  #RandAug
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  #Imagenet mean & std
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
train_folder = r"C:\Users\dhani\Documents\Tugas Akhir and Stuff\Dataset Manual\train"
test_folder = r"C:\Users\dhani\Documents\Tugas Akhir and Stuff\Dataset Manual\test"

train_dataset = ImageFolder(root=train_folder, transform=train_transform)
test_dataset = ImageFolder(root=test_folder, transform=test_transform)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train dataset: {len(train_dataset)} images, {len(train_dataset.classes)} classes.")
print(f"Test dataset: {len(test_dataset)} images, {len(test_dataset.classes)} classes.")
# Out:
# Train dataset: 3120 images, 52 classes.
# Test dataset: 2080 images, 52 classes.

# %%
from torchvision.models import resnet34, ResNet34_Weights, resnet50, ResNet50_Weights, resnet101,ResNet101_Weights

weights34 = ResNet34_Weights.IMAGENET1K_V1
weights50 = ResNet50_Weights.IMAGENET1K_V1
weights101 = ResNet101_Weights.IMAGENET1K_V1
model = resnet50(weights=weights50)

#freeze conv
for param in model.parameters():
    param.requires_grad = False

# fc layer config
num_classes = 52
# zerolayer
# model.fc = nn.Linear(model.fc.in_features, num_classes)  

# onelayer
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 512),
    nn.ReLU(),
    nn.Linear(512, num_classes)        
)       

# twolayer
# model.fc = nn.Sequential(
#     nn.Linear(model.fc.in_features, 512),
#     nn.ReLU(),
#     nn.Linear(512, 512),
#     nn.ReLU(),
#     nn.Linear(512, num_classes)        
# )                                                      

#parameter set
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.fc.parameters(), lr=0.001)

device = torch.device('cuda')
model = model.to(device)

# %%
import pandas as pd
import torch
import torch.nn as nn
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import time

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_f1_scores = []
val_f1_scores = []

total_start_time = time.time()

num_epochs = 50

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    all_train_labels = []
    all_train_preds = []

    start_time = time.time()

    # Train loop
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        # Forwardprop
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        all_train_labels.extend(labels.cpu().numpy())
        all_train_preds.extend(predicted.cpu().numpy())

    # Train loss, accuracy, F1 score
    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train
    train_f1 = f1_score(all_train_labels, all_train_preds, average='macro')

    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    train_f1_scores.append(train_f1)

    # Validation loop
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    all_val_labels = []
    all_val_preds = []
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

            all_val_labels.extend(labels.cpu().numpy())
            all_val_preds.extend(predicted.cpu().numpy())

    # Val loss, accuracy,  F1 score
    val_loss = val_loss / len(test_loader)
    val_accuracy = 100 * correct_val / total_val
    val_f1 = f1_score(all_val_labels, all_val_preds, average='macro')

    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)
    val_f1_scores.append(val_f1)

    epoch_time = time.time() - start_time

    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, "
          f"Train Accuracy: {train_accuracy:.2f}%, Val Accuracy: {val_accuracy:.2f}%, "
          f"Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}, Time: {epoch_time:.2f} seconds")

total_training_time = time.time() - total_start_time
print(f"Total Training Time: {total_training_time:.2f} seconds")

results_df = pd.DataFrame({
    'Epoch': range(1, num_epochs + 1),
    'Train Loss': train_losses,
    'Val Loss': val_losses,
    'Train Accuracy': train_accuracies,
    'Val Accuracy': val_accuracies,
    'Train F1 Score': train_f1_scores,
    'Val F1 Score': val_f1_scores
})
results_df.to_csv('training_results_with_50_1.csv', index=False)
# Out:
# Epoch [1/50], Train Loss: 2.7454, Val Loss: 1.2811, Train Accuracy: 34.36%, Val Accuracy: 71.15%, Train F1: 0.3385, Val F1: 0.6832, Time: 34.41 seconds
# Epoch [2/50], Train Loss: 1.2323, Val Loss: 0.6401, Train Accuracy: 68.40%, Val Accuracy: 84.42%, Train F1: 0.6790, Val F1: 0.8363, Time: 34.80 seconds
# Epoch [3/50], Train Loss: 0.8453, Val Loss: 0.4645, Train Accuracy: 77.05%, Val Accuracy: 87.12%, Train F1: 0.7666, Val F1: 0.8700, Time: 35.65 seconds
# Epoch [4/50], Train Loss: 0.6735, Val Loss: 0.3798, Train Accuracy: 80.64%, Val Accuracy: 89.66%, Train F1: 0.8047, Val F1: 0.8972, Time: 35.95 seconds
# Epoch [5/50], Train Loss: 0.6049, Val Loss: 0.3432, Train Accuracy: 82.15%, Val Accuracy: 89.71%, Train F1: 0.8198, Val F1: 0.8936, Time: 36.38 seconds
# Epoch [6/50], Train Loss: 0.5138, Val Loss: 0.2865, Train Accuracy: 84.84%, Val Accuracy: 91.97%, Train F1: 0.8478, Val F1: 0.9192, Time: 36.31 seconds
# Epoch [7/50], Train Loss: 0.4436, Val Loss: 0.2527, Train Accuracy: 86.76%, Val Accuracy: 92.21%, Train F1: 0.8666, Val F1: 0.9233, Time: 36.69 seconds
# Epoch [8/50], Train Loss: 0.4256, Val Loss: 0.2150, Train Accuracy: 87.15%, Val Accuracy: 93.12%, Train F1: 0.8711, Val F1: 0.9298, Time: 36.95 seconds
# Epoch [9/50], Train Loss: 0.3990, Val Loss: 0.2321, Train Accuracy: 88.04%, Val Accuracy: 92.50%, Train F1: 0.8805, Val F1: 0.9245, Time: 36.73 seconds
# Epoch [10/50], Train Loss: 0.3938, Val Loss: 0.2704, Train Accuracy: 88.08%, Val Accuracy: 91.97%, Train F1: 0.8804, Val F1: 0.9185, Time: 36.48 seconds
# Epoch [11/50], Train Loss: 0.3737, Val Loss: 0.2142, Train Accuracy: 88.53%, Val Accuracy: 93.27%, Train F1: 0.8847, Val F1: 0.9323, Time: 36.69 seconds
# Epoch [12/50], Train Loss: 0.3672, Val Loss: 0.2304, Train Accuracy: 88.56%, Val Accuracy: 93.03%, Train F1: 0.8853, Val F1: 0.9296, Time: 36.79 seconds
# Epoch [13/50], Train Loss: 0.3321, Val Loss: 0.2067, Train Accuracy: 90.29%, Val Accuracy: 93.41%, Train F1: 0.9029, Val F1: 0.9344, Time: 36.82 seconds
# Epoch [14/50], Train Loss: 0.3219, Val Loss: 0.2246, Train Accuracy: 89.71%, Val Accuracy: 92.45%, Train F1: 0.8970, Val F1: 0.9222, Time: 36.88 seconds
# Epoch [15/50], Train Loss: 0.3006, Val Loss: 0.2132, Train Accuracy: 90.87%, Val Accuracy: 92.93%, Train F1: 0.9085, Val F1: 0.9319, Time: 36.68 seconds
# Epoch [16/50], Train Loss: 0.2966, Val Loss: 0.2181, Train Accuracy: 90.42%, Val Accuracy: 93.12%, Train F1: 0.9041, Val F1: 0.9307, Time: 36.84 seconds
# Epoch [17/50], Train Loss: 0.3355, Val Loss: 0.1786, Train Accuracy: 89.71%, Val Accuracy: 94.66%, Train F1: 0.8967, Val F1: 0.9466, Time: 36.79 seconds
# Epoch [18/50], Train Loss: 0.2721, Val Loss: 0.1565, Train Accuracy: 91.51%, Val Accuracy: 95.14%, Train F1: 0.9151, Val F1: 0.9513, Time: 36.79 seconds
# Epoch [19/50], Train Loss: 0.2957, Val Loss: 0.2062, Train Accuracy: 90.54%, Val Accuracy: 93.61%, Train F1: 0.9053, Val F1: 0.9331, Time: 36.74 seconds
# Epoch [20/50], Train Loss: 0.2743, Val Loss: 0.1754, Train Accuracy: 91.47%, Val Accuracy: 94.47%, Train F1: 0.9147, Val F1: 0.9450, Time: 36.93 seconds
# Epoch [21/50], Train Loss: 0.2532, Val Loss: 0.1731, Train Accuracy: 91.96%, Val Accuracy: 94.57%, Train F1: 0.9193, Val F1: 0.9460, Time: 36.73 seconds
# Epoch [22/50], Train Loss: 0.2510, Val Loss: 0.1578, Train Accuracy: 92.47%, Val Accuracy: 95.62%, Train F1: 0.9246, Val F1: 0.9568, Time: 37.14 seconds
# Epoch [23/50], Train Loss: 0.2746, Val Loss: 0.1491, Train Accuracy: 91.54%, Val Accuracy: 95.87%, Train F1: 0.9152, Val F1: 0.9589, Time: 36.68 seconds
# Epoch [24/50], Train Loss: 0.2770, Val Loss: 0.1724, Train Accuracy: 90.93%, Val Accuracy: 95.05%, Train F1: 0.9090, Val F1: 0.9495, Time: 37.16 seconds
# Epoch [25/50], Train Loss: 0.2568, Val Loss: 0.1367, Train Accuracy: 92.24%, Val Accuracy: 95.72%, Train F1: 0.9224, Val F1: 0.9570, Time: 37.48 seconds
# Epoch [26/50], Train Loss: 0.2150, Val Loss: 0.1422, Train Accuracy: 92.63%, Val Accuracy: 95.72%, Train F1: 0.9261, Val F1: 0.9571, Time: 38.61 seconds
# Epoch [27/50], Train Loss: 0.2642, Val Loss: 0.1573, Train Accuracy: 91.92%, Val Accuracy: 95.10%, Train F1: 0.9191, Val F1: 0.9507, Time: 39.02 seconds
# Epoch [28/50], Train Loss: 0.2383, Val Loss: 0.1610, Train Accuracy: 92.28%, Val Accuracy: 95.14%, Train F1: 0.9227, Val F1: 0.9515, Time: 38.83 seconds
# Epoch [29/50], Train Loss: 0.2398, Val Loss: 0.1603, Train Accuracy: 91.57%, Val Accuracy: 95.48%, Train F1: 0.9157, Val F1: 0.9548, Time: 38.92 seconds
# Epoch [30/50], Train Loss: 0.1928, Val Loss: 0.1302, Train Accuracy: 94.49%, Val Accuracy: 96.20%, Train F1: 0.9447, Val F1: 0.9623, Time: 38.85 seconds
# Epoch [31/50], Train Loss: 0.2087, Val Loss: 0.1442, Train Accuracy: 93.69%, Val Accuracy: 95.24%, Train F1: 0.9366, Val F1: 0.9526, Time: 38.77 seconds
# Epoch [32/50], Train Loss: 0.2324, Val Loss: 0.1343, Train Accuracy: 92.82%, Val Accuracy: 96.06%, Train F1: 0.9281, Val F1: 0.9604, Time: 39.08 seconds
# Epoch [33/50], Train Loss: 0.2098, Val Loss: 0.1357, Train Accuracy: 93.17%, Val Accuracy: 96.11%, Train F1: 0.9315, Val F1: 0.9610, Time: 39.56 seconds
# Epoch [34/50], Train Loss: 0.2111, Val Loss: 0.1318, Train Accuracy: 93.21%, Val Accuracy: 96.35%, Train F1: 0.9320, Val F1: 0.9634, Time: 39.28 seconds
# Epoch [35/50], Train Loss: 0.2078, Val Loss: 0.1368, Train Accuracy: 93.53%, Val Accuracy: 95.14%, Train F1: 0.9354, Val F1: 0.9511, Time: 38.54 seconds
# Epoch [36/50], Train Loss: 0.2175, Val Loss: 0.1716, Train Accuracy: 92.98%, Val Accuracy: 93.94%, Train F1: 0.9296, Val F1: 0.9367, Time: 38.67 seconds
# Epoch [37/50], Train Loss: 0.2153, Val Loss: 0.1194, Train Accuracy: 93.59%, Val Accuracy: 96.44%, Train F1: 0.9357, Val F1: 0.9644, Time: 38.76 seconds
# Epoch [38/50], Train Loss: 0.1952, Val Loss: 0.1496, Train Accuracy: 93.85%, Val Accuracy: 94.90%, Train F1: 0.9384, Val F1: 0.9492, Time: 39.11 seconds
# Epoch [39/50], Train Loss: 0.2193, Val Loss: 0.1130, Train Accuracy: 92.79%, Val Accuracy: 96.54%, Train F1: 0.9277, Val F1: 0.9655, Time: 39.15 seconds
# Epoch [40/50], Train Loss: 0.2188, Val Loss: 0.1577, Train Accuracy: 93.59%, Val Accuracy: 95.05%, Train F1: 0.9359, Val F1: 0.9501, Time: 38.85 seconds
# Epoch [41/50], Train Loss: 0.2073, Val Loss: 0.1420, Train Accuracy: 93.53%, Val Accuracy: 95.38%, Train F1: 0.9351, Val F1: 0.9544, Time: 38.82 seconds
# Epoch [42/50], Train Loss: 0.1968, Val Loss: 0.1529, Train Accuracy: 93.91%, Val Accuracy: 95.34%, Train F1: 0.9389, Val F1: 0.9532, Time: 39.03 seconds
# Epoch [43/50], Train Loss: 0.1827, Val Loss: 0.1699, Train Accuracy: 94.01%, Val Accuracy: 94.42%, Train F1: 0.9400, Val F1: 0.9437, Time: 38.99 seconds
# Epoch [44/50], Train Loss: 0.2027, Val Loss: 0.1441, Train Accuracy: 93.81%, Val Accuracy: 95.77%, Train F1: 0.9380, Val F1: 0.9582, Time: 39.25 seconds
# Epoch [45/50], Train Loss: 0.1935, Val Loss: 0.1524, Train Accuracy: 93.81%, Val Accuracy: 95.19%, Train F1: 0.9382, Val F1: 0.9518, Time: 38.71 seconds
# Epoch [46/50], Train Loss: 0.1848, Val Loss: 0.1524, Train Accuracy: 93.75%, Val Accuracy: 95.34%, Train F1: 0.9373, Val F1: 0.9533, Time: 38.96 seconds
# Epoch [47/50], Train Loss: 0.1847, Val Loss: 0.1368, Train Accuracy: 94.46%, Val Accuracy: 95.91%, Train F1: 0.9446, Val F1: 0.9593, Time: 39.04 seconds
# Epoch [48/50], Train Loss: 0.2120, Val Loss: 0.1741, Train Accuracy: 93.65%, Val Accuracy: 95.48%, Train F1: 0.9364, Val F1: 0.9543, Time: 38.85 seconds
# Epoch [49/50], Train Loss: 0.2195, Val Loss: 0.1280, Train Accuracy: 93.21%, Val Accuracy: 96.39%, Train F1: 0.9321, Val F1: 0.9638, Time: 39.61 seconds
# Epoch [50/50], Train Loss: 0.1957, Val Loss: 0.1195, Train Accuracy: 93.81%, Val Accuracy: 96.59%, Train F1: 0.9383, Val F1: 0.9658, Time: 39.12 seconds
# Total Training Time: 1887.89 seconds

# %%
#savemodel
torch.save(model.state_dict(), "resnet50_OneLayer.pth")
