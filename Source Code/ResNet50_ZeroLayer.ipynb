# %% [markdown]
# # ResNet-50 Transfer Learning for Plant Classification
# Zero Additional Hidden Layer

# %%
import torch
import torch.nn as nn
from torch.optim import Adam
from torchvision import models, transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import RandAugment
import matplotlib.pyplot as plt
import time

# %%
train_transform = transforms.Compose([
    RandAugment(),  #RandAug
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  #Imagenet mean & std
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
train_folder = r"C:\Users\dhani\Documents\Tugas Akhir and Stuff\Dataset Manual\train"
test_folder = r"C:\Users\dhani\Documents\Tugas Akhir and Stuff\Dataset Manual\test"

train_dataset = ImageFolder(root=train_folder, transform=train_transform)
test_dataset = ImageFolder(root=test_folder, transform=test_transform)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train dataset: {len(train_dataset)} images, {len(train_dataset.classes)} classes.")
print(f"Test dataset: {len(test_dataset)} images, {len(test_dataset.classes)} classes.")
# Out:
# Train dataset: 3120 images, 52 classes.
# Test dataset: 2080 images, 52 classes.

# %%
from torchvision.models import resnet34, ResNet34_Weights, resnet50, ResNet50_Weights, resnet101,ResNet101_Weights

weights34 = ResNet34_Weights.IMAGENET1K_V1
weights50 = ResNet50_Weights.IMAGENET1K_V1
weights101 = ResNet101_Weights.IMAGENET1K_V1
model = resnet50(weights=weights50)

#freeze conv
for param in model.parameters():
    param.requires_grad = False

# fc layer config
num_classes = 52
# zerolayer
model.fc = nn.Linear(model.fc.in_features, num_classes)  

# onelayer
# model.fc = nn.Sequential(
#     nn.Linear(model.fc.in_features, 512),
#     nn.ReLU(),
#     nn.Linear(512, num_classes)        
# )       

# twolayer
# model.fc = nn.Sequential(
#     nn.Linear(model.fc.in_features, 512),
#     nn.ReLU(),
#     nn.Linear(512, 512),
#     nn.ReLU(),
#     nn.Linear(512, num_classes)        
# )                                                      

#parameter set
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.fc.parameters(), lr=0.001)

device = torch.device('cuda')
model = model.to(device)

# %%
import pandas as pd
import torch
import torch.nn as nn
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import time

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_f1_scores = []
val_f1_scores = []

total_start_time = time.time()

num_epochs = 50

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    all_train_labels = []
    all_train_preds = []

    start_time = time.time()

    # Train loop
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        # Forwardprop
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        all_train_labels.extend(labels.cpu().numpy())
        all_train_preds.extend(predicted.cpu().numpy())

    # Train loss, accuracy, F1 score
    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train
    train_f1 = f1_score(all_train_labels, all_train_preds, average='macro')

    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    train_f1_scores.append(train_f1)

    # Validation loop
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    all_val_labels = []
    all_val_preds = []
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

            all_val_labels.extend(labels.cpu().numpy())
            all_val_preds.extend(predicted.cpu().numpy())

    # Val loss, accuracy,  F1 score
    val_loss = val_loss / len(test_loader)
    val_accuracy = 100 * correct_val / total_val
    val_f1 = f1_score(all_val_labels, all_val_preds, average='macro')

    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)
    val_f1_scores.append(val_f1)

    epoch_time = time.time() - start_time

    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, "
          f"Train Accuracy: {train_accuracy:.2f}%, Val Accuracy: {val_accuracy:.2f}%, "
          f"Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}, Time: {epoch_time:.2f} seconds")

total_training_time = time.time() - total_start_time
print(f"Total Training Time: {total_training_time:.2f} seconds")

results_df = pd.DataFrame({
    'Epoch': range(1, num_epochs + 1),
    'Train Loss': train_losses,
    'Val Loss': val_losses,
    'Train Accuracy': train_accuracies,
    'Val Accuracy': val_accuracies,
    'Train F1 Score': train_f1_scores,
    'Val F1 Score': val_f1_scores
})
results_df.to_csv('training_results_with_50_0.csv', index=False)
# Out:
# Epoch [1/50], Train Loss: 2.5743, Val Loss: 1.1174, Train Accuracy: 43.27%, Val Accuracy: 80.05%, Train F1: 0.4330, Val F1: 0.7910, Time: 34.45 seconds
# Epoch [2/50], Train Loss: 1.1941, Val Loss: 0.6010, Train Accuracy: 74.39%, Val Accuracy: 87.88%, Train F1: 0.7410, Val F1: 0.8772, Time: 34.35 seconds
# Epoch [3/50], Train Loss: 0.8253, Val Loss: 0.4862, Train Accuracy: 82.31%, Val Accuracy: 88.85%, Train F1: 0.8204, Val F1: 0.8938, Time: 35.10 seconds
# Epoch [4/50], Train Loss: 0.6461, Val Loss: 0.3830, Train Accuracy: 85.42%, Val Accuracy: 91.88%, Train F1: 0.8540, Val F1: 0.9184, Time: 35.71 seconds
# Epoch [5/50], Train Loss: 0.5707, Val Loss: 0.3378, Train Accuracy: 86.31%, Val Accuracy: 91.88%, Train F1: 0.8625, Val F1: 0.9176, Time: 35.95 seconds
# Epoch [6/50], Train Loss: 0.5023, Val Loss: 0.2953, Train Accuracy: 87.56%, Val Accuracy: 92.60%, Train F1: 0.8756, Val F1: 0.9263, Time: 36.03 seconds
# Epoch [7/50], Train Loss: 0.4522, Val Loss: 0.2668, Train Accuracy: 89.29%, Val Accuracy: 93.56%, Train F1: 0.8926, Val F1: 0.9357, Time: 36.20 seconds
# Epoch [8/50], Train Loss: 0.4230, Val Loss: 0.2306, Train Accuracy: 89.65%, Val Accuracy: 94.33%, Train F1: 0.8960, Val F1: 0.9439, Time: 36.12 seconds
# Epoch [9/50], Train Loss: 0.3684, Val Loss: 0.2194, Train Accuracy: 91.09%, Val Accuracy: 94.47%, Train F1: 0.9106, Val F1: 0.9447, Time: 36.41 seconds
# Epoch [10/50], Train Loss: 0.3740, Val Loss: 0.2255, Train Accuracy: 90.35%, Val Accuracy: 94.42%, Train F1: 0.9032, Val F1: 0.9439, Time: 36.31 seconds
# Epoch [11/50], Train Loss: 0.3498, Val Loss: 0.2012, Train Accuracy: 90.45%, Val Accuracy: 94.28%, Train F1: 0.9043, Val F1: 0.9424, Time: 36.26 seconds
# Epoch [12/50], Train Loss: 0.3522, Val Loss: 0.2094, Train Accuracy: 90.13%, Val Accuracy: 93.80%, Train F1: 0.9009, Val F1: 0.9378, Time: 36.22 seconds
# Epoch [13/50], Train Loss: 0.3146, Val Loss: 0.2008, Train Accuracy: 91.76%, Val Accuracy: 94.38%, Train F1: 0.9177, Val F1: 0.9433, Time: 36.43 seconds
# Epoch [14/50], Train Loss: 0.3240, Val Loss: 0.1933, Train Accuracy: 90.58%, Val Accuracy: 94.66%, Train F1: 0.9055, Val F1: 0.9465, Time: 36.35 seconds
# Epoch [15/50], Train Loss: 0.3138, Val Loss: 0.1652, Train Accuracy: 91.51%, Val Accuracy: 96.06%, Train F1: 0.9151, Val F1: 0.9606, Time: 36.26 seconds
# Epoch [16/50], Train Loss: 0.2761, Val Loss: 0.1611, Train Accuracy: 92.66%, Val Accuracy: 95.58%, Train F1: 0.9262, Val F1: 0.9561, Time: 36.44 seconds
# Epoch [17/50], Train Loss: 0.2678, Val Loss: 0.1742, Train Accuracy: 92.85%, Val Accuracy: 95.00%, Train F1: 0.9285, Val F1: 0.9502, Time: 36.69 seconds
# Epoch [18/50], Train Loss: 0.2570, Val Loss: 0.1530, Train Accuracy: 93.08%, Val Accuracy: 95.53%, Train F1: 0.9307, Val F1: 0.9555, Time: 36.24 seconds
# Epoch [19/50], Train Loss: 0.2644, Val Loss: 0.1489, Train Accuracy: 92.24%, Val Accuracy: 96.15%, Train F1: 0.9226, Val F1: 0.9615, Time: 36.37 seconds
# Epoch [20/50], Train Loss: 0.2488, Val Loss: 0.1603, Train Accuracy: 93.01%, Val Accuracy: 95.53%, Train F1: 0.9299, Val F1: 0.9554, Time: 36.59 seconds
# Epoch [21/50], Train Loss: 0.2363, Val Loss: 0.1678, Train Accuracy: 93.30%, Val Accuracy: 94.86%, Train F1: 0.9330, Val F1: 0.9487, Time: 36.54 seconds
# Epoch [22/50], Train Loss: 0.2471, Val Loss: 0.1700, Train Accuracy: 93.14%, Val Accuracy: 94.76%, Train F1: 0.9310, Val F1: 0.9485, Time: 36.83 seconds
# Epoch [23/50], Train Loss: 0.2376, Val Loss: 0.1649, Train Accuracy: 93.17%, Val Accuracy: 94.62%, Train F1: 0.9315, Val F1: 0.9461, Time: 37.17 seconds
# Epoch [24/50], Train Loss: 0.2306, Val Loss: 0.1457, Train Accuracy: 93.62%, Val Accuracy: 95.87%, Train F1: 0.9362, Val F1: 0.9589, Time: 36.87 seconds
# Epoch [25/50], Train Loss: 0.2501, Val Loss: 0.1480, Train Accuracy: 92.28%, Val Accuracy: 95.58%, Train F1: 0.9229, Val F1: 0.9559, Time: 36.61 seconds
# Epoch [26/50], Train Loss: 0.2240, Val Loss: 0.1538, Train Accuracy: 93.17%, Val Accuracy: 95.38%, Train F1: 0.9315, Val F1: 0.9530, Time: 36.61 seconds
# Epoch [27/50], Train Loss: 0.2164, Val Loss: 0.1382, Train Accuracy: 93.72%, Val Accuracy: 95.67%, Train F1: 0.9370, Val F1: 0.9568, Time: 36.73 seconds
# Epoch [28/50], Train Loss: 0.2121, Val Loss: 0.1307, Train Accuracy: 93.30%, Val Accuracy: 96.44%, Train F1: 0.9328, Val F1: 0.9643, Time: 37.44 seconds
# Epoch [29/50], Train Loss: 0.2232, Val Loss: 0.1278, Train Accuracy: 93.53%, Val Accuracy: 96.15%, Train F1: 0.9351, Val F1: 0.9611, Time: 38.67 seconds
# Epoch [30/50], Train Loss: 0.1959, Val Loss: 0.1435, Train Accuracy: 94.33%, Val Accuracy: 95.29%, Train F1: 0.9431, Val F1: 0.9531, Time: 38.74 seconds
# Epoch [31/50], Train Loss: 0.1869, Val Loss: 0.1338, Train Accuracy: 94.74%, Val Accuracy: 95.96%, Train F1: 0.9474, Val F1: 0.9594, Time: 38.88 seconds
# Epoch [32/50], Train Loss: 0.2000, Val Loss: 0.1593, Train Accuracy: 94.39%, Val Accuracy: 95.34%, Train F1: 0.9439, Val F1: 0.9534, Time: 38.55 seconds
# Epoch [33/50], Train Loss: 0.2213, Val Loss: 0.1303, Train Accuracy: 93.11%, Val Accuracy: 95.96%, Train F1: 0.9311, Val F1: 0.9592, Time: 38.65 seconds
# Epoch [34/50], Train Loss: 0.1873, Val Loss: 0.1335, Train Accuracy: 94.68%, Val Accuracy: 95.96%, Train F1: 0.9467, Val F1: 0.9598, Time: 38.56 seconds
# Epoch [35/50], Train Loss: 0.1867, Val Loss: 0.1305, Train Accuracy: 94.36%, Val Accuracy: 95.87%, Train F1: 0.9436, Val F1: 0.9587, Time: 38.30 seconds
# Epoch [36/50], Train Loss: 0.1834, Val Loss: 0.1359, Train Accuracy: 94.65%, Val Accuracy: 95.77%, Train F1: 0.9464, Val F1: 0.9578, Time: 36.92 seconds
# Epoch [37/50], Train Loss: 0.1733, Val Loss: 0.1369, Train Accuracy: 94.90%, Val Accuracy: 95.82%, Train F1: 0.9488, Val F1: 0.9578, Time: 36.93 seconds
# Epoch [38/50], Train Loss: 0.1833, Val Loss: 0.1260, Train Accuracy: 94.65%, Val Accuracy: 96.01%, Train F1: 0.9465, Val F1: 0.9601, Time: 36.88 seconds
# Epoch [39/50], Train Loss: 0.1826, Val Loss: 0.1260, Train Accuracy: 94.29%, Val Accuracy: 96.15%, Train F1: 0.9429, Val F1: 0.9614, Time: 37.06 seconds
# Epoch [40/50], Train Loss: 0.1729, Val Loss: 0.1232, Train Accuracy: 94.71%, Val Accuracy: 96.30%, Train F1: 0.9472, Val F1: 0.9631, Time: 36.84 seconds
# Epoch [41/50], Train Loss: 0.1815, Val Loss: 0.1229, Train Accuracy: 94.52%, Val Accuracy: 95.91%, Train F1: 0.9452, Val F1: 0.9593, Time: 36.68 seconds
# Epoch [42/50], Train Loss: 0.1713, Val Loss: 0.1205, Train Accuracy: 95.16%, Val Accuracy: 96.20%, Train F1: 0.9514, Val F1: 0.9620, Time: 37.05 seconds
# Epoch [43/50], Train Loss: 0.1649, Val Loss: 0.1462, Train Accuracy: 94.65%, Val Accuracy: 95.10%, Train F1: 0.9463, Val F1: 0.9518, Time: 36.65 seconds
# Epoch [44/50], Train Loss: 0.1696, Val Loss: 0.1226, Train Accuracy: 95.00%, Val Accuracy: 96.01%, Train F1: 0.9499, Val F1: 0.9604, Time: 36.92 seconds
# Epoch [45/50], Train Loss: 0.1904, Val Loss: 0.1240, Train Accuracy: 93.81%, Val Accuracy: 96.15%, Train F1: 0.9382, Val F1: 0.9620, Time: 36.48 seconds
# Epoch [46/50], Train Loss: 0.1629, Val Loss: 0.1212, Train Accuracy: 95.16%, Val Accuracy: 95.91%, Train F1: 0.9517, Val F1: 0.9592, Time: 36.68 seconds
# Epoch [47/50], Train Loss: 0.1750, Val Loss: 0.1208, Train Accuracy: 94.33%, Val Accuracy: 96.39%, Train F1: 0.9432, Val F1: 0.9638, Time: 36.63 seconds
# Epoch [48/50], Train Loss: 0.1615, Val Loss: 0.1105, Train Accuracy: 95.03%, Val Accuracy: 96.88%, Train F1: 0.9504, Val F1: 0.9689, Time: 36.78 seconds
# Epoch [49/50], Train Loss: 0.1722, Val Loss: 0.1429, Train Accuracy: 94.23%, Val Accuracy: 95.48%, Train F1: 0.9423, Val F1: 0.9550, Time: 36.83 seconds
# Epoch [50/50], Train Loss: 0.1826, Val Loss: 0.1345, Train Accuracy: 94.23%, Val Accuracy: 96.06%, Train F1: 0.9423, Val F1: 0.9608, Time: 36.67 seconds
# Total Training Time: 1837.71 seconds

# %%
#savemodel
torch.save(model.state_dict(), "resnet50_ZeroLayer.pth")
